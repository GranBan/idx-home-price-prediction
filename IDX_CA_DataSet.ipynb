# %%
import pandas as pd
import glob
import os

# Load all CSVs at once
files = glob.glob('/Users/granthbangard/Local Files/Documents/granth/UIUC/IDXExchange/DataSet/CRMLSSold*.csv')
df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

# Basic orientation
print('Shape:', df.shape)
print(df.columns.tolist())
print(df.dtypes)
print(df.isnull().sum())
# Out:
# /var/folders/n_/hd4whr8972b54sv4t6_db9d80000gn/T/ipykernel_85933/221336678.py:7: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# /var/folders/n_/hd4whr8972b54sv4t6_db9d80000gn/T/ipykernel_85933/221336678.py:7: DtypeWarning: Columns (78,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# /var/folders/n_/hd4whr8972b54sv4t6_db9d80000gn/T/ipykernel_85933/221336678.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# /var/folders/n_/hd4whr8972b54sv4t6_db9d80000gn/T/ipykernel_85933/221336678.py:7: DtypeWarning: Columns (4,74) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df_sfr = df[(df['PropertyType'] == 'Residential') & (df['PropertySubType'] == 'SingleFamilyResidence')]

print('shape:', df_sfr.shape, '\n')
print(df_sfr[['ClosePrice', 'Latitude', 'Longitude', 'ElementarySchoolDistrict', 'HighSchoolDistrict', 'latfilled', 'lonfilled']].isnull().sum())
# Out:
# shape: (399157, 82)
#
# ClosePrice                       2
# Latitude                       193
# Longitude                      193
# ElementarySchoolDistrict    399157
# HighSchoolDistrict          103300
# latfilled                   230343
# lonfilled                   230343
# dtype: int64
